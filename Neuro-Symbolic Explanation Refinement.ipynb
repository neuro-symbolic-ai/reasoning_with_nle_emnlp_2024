# %% [markdown]
# # LLM-Symbolic Explanation Refinement
#
# Given a premise sentence $p_i$, a hypothesis sentence $h_i$, and an explanation $E_i$ consisting of a set of facts $\{f_1,f_2,...,f_n\}$, the explanation $E_i$ is considered logically valid if and only if the entailment $p_i \cup E_i \models h_i$ holds. This entailment is considered verifiable if $\{p_i, E_i, h_i\}$ can be translated into a set of logical formulae $\Phi$ that compose a theory $\Theta$. The validity of the theory $\Theta$ is subsequently determined by a theorem prover, verifying whether $\Theta \vDash \psi$, where $\psi$ represents a logical consequence derived from the logical form of $h_i$.
#
# <img src="figures/nesy_refinement.png">
#
# <img src="figures/nesy_refinement_results.png">

# %% [markdown]
# ## Explanation Refinement (e-SNLI)
#
# Premise: A couple playing with a little boy on the beach.
#
# Hypothesis: "A couple are playing with a young child outside.
#
# Annotated Explanation: little boy is a young child.

# %%
from refinement.refinement_model import RefinementModel
from generation.generative_model import GPT
from critique.critique_model import IsabelleSolver
import yaml

# data name is default to example_data
# premise and explanation are default to None
# explanation sentences need to be seperate by '\n'
data_name = 'esnli_0'
premise = "A couple playing with a little boy on the beach."
hypothesis = "A couple are playing with a young child outside."
explanation = "little boy is a young child."


llm = GPT('gpt-4o-mini', api_key)

isabelle_solver = IsabelleSolver(
    generative_model=llm,
    isabelle_session = 'HOL',
    theory_name = data_name
)

# prompts can be modifed, but defaults to following dictionary
# prompt_dict = {
#     'generate explanation': 'get_explanation_prompt.txt',
#     'refine logical error no premise': 'refine_logical_error_no_premise_prompt.txt',
#     'refine logical error with premise': 'refine_logical_error_with_premise_prompt.txt'
# }
refinement_model = RefinementModel(
    generative_model=llm,
    critique_model=isabelle_solver,
)

# premise and explanation are optional
# iterative refinement times are set to 10 by default
results = refinement_model.refine(
    hypothesis = hypothesis,
    premise = premise,
    explanation = explanation,
    data_name = data_name,
)

isabelle_solver.shutdown()
# Out:
# ================= Iteration Number 0 ==================
#
# Premise: A couple playing with a little boy on the beach.
# Hypothesis: A couple playing with a little boy on the beach.
# Explanation:
# 1. little boy is a young child
#
# -------------- Verification and Refinement -------------------
#
# ------------------ 1) Syntactic Parsing ------------------
#
# Hypothesis Sentence:
# 1. A couple are playing with a young child outside
# Subject: A couple
# Verb Phrase: are playing with a young child outside
#  - Main Verb: playing
#  - Auxiliary Verb: are
# Direct Object: a young child
# Adverbial Modifier (Location): outside
#
# Explanation Sentence:
# 1. little boy is a young child
# Subject: little boy
# Linking Verb: is
# Subject Complement: a young child
#
# Premise Sentence:
# 1. A couple playing with a little boy on the beach
# Subject: A couple
# Verb Phrase: playing with a little boy on the beach
#  - Main Verb: playing
# Direct Object: a little boy
# Adverbial Modifier (Location): on the beach
#
# ------------------ 2) Neodavidsonian From ------------------
#
# Hypothesis Sentence:
# 1. A couple are playing with a young child outside.
# Logical form: ∃x y z e. Couple(x) ∧ YoungChild(y) ∧ Playing(e) ∧ Agent(e, x) ∧ Patient(e, y) ∧ Outside(e)
#
# Explanation Sentence:
# 1. A little boy is a young child.
# Logical form: ∀x. LittleBoy(x) ⟶ YoungChild(x)
#
# Premise Sentence:
# 1. A couple playing with a little boy on the beach.
# Logical form: ∃x y z e. Couple(x) ∧ LittleBoy(y) ∧ Playing(e) ∧ Agent(e, x) ∧ Patient(e, y) ∧ OnBeach(e)
#
# ------------------ 3) Isabelle Code ------------------
#
# theory esnli_0_0
# imports Main
#
# begin
#
# typedecl entity
# typedecl event
#
# consts
#   LittleBoy :: "entity ⇒ bool"
#   YoungChild :: "entity ⇒ bool"
#   Couple :: "entity ⇒ bool"
#   Playing :: "event ⇒ bool"
#   Agent :: "event ⇒ entity ⇒ bool"
#   Patient :: "event ⇒ entity ⇒ bool"
#   Outside :: "event ⇒ bool"
#   OnBeach :: "event ⇒ bool"
#
# (* Explanation 1: A little boy is a young child. *)
# axiomatization where
#   explanation_1: "∀x. LittleBoy x ⟶ YoungChild x"
#
# theorem hypothesis:
#   (* Premise 1: A couple playing with a little boy on the beach. *)
#   assumes asm: "Couple x ∧ LittleBoy y ∧ Playing e ∧ Agent e x ∧ Patient e y ∧ OnBeach e"
#   (* Hypothesis: A couple are playing with a young child outside. *)
#   shows "∃x y z e. Couple x ∧ YoungChild y ∧ Playing e ∧ Agent e x ∧ Patient e y ∧ Outside e"
# proof -
#   (* From the premise, we can extract the known information about the couple, little boy, playing, agent, and patient. *)
#   from asm have "Couple x ∧ LittleBoy y ∧ Playing e ∧ Agent e x ∧ Patient e y ∧ OnBeach e" <ATP>
#   (* We have the logical relation that a little boy is a young child from the explanation sentence. *)
#   (* Therefore, we can infer that YoungChild y holds. *)
#   then have "Couple x ∧ YoungChild y ∧ Playing e ∧ Agent e x ∧ Patient e y ∧ OnBeach e" <ATP>
#   (* We need to show that the event is outside. Since the premise states they are on the beach, we can infer that they are outside. *)
#   then have "Outside e" <ATP>
#   (* Now we can combine everything to show the hypothesis. *)
#   then show ?thesis <ATP>
# qed
#
# end
#
#
# -------------- 4) Results -------------------
#
# No proof can be found!The explanation is not logically valid! Refinement...
#
# -------------- 5) Refinement Feedback -------------------
#
# Error:
# (* We need to show that the event is outside. Since the premise states they are on the beach, we can infer that they are outside. *)
# then have "Outside e" sledgehammer
#
# Logical information:
# Logical Propositions:
# A: little boy (from Explanatory Sentence 1)
# B: young child (from Explanatory Sentence 1)
#
# Logical Relations:
# Equivalent(A, B)
# Equivalent(little boy, young child)
# --------
#
# Derived Implications:
# Implies(B, A)
# Implies(young child, little boy)
# --------
# Implies(Not(A), Not(B))
# Implies(Not(little boy), Not(young child))
# --------
# Implies(A, B)
# Implies(little boy, young child)
# --------
# Implies(Not(B), Not(A))
# Implies(Not(young child), Not(little boy))
# --------
#
#
# -------------- 6) Refined Explanation -------------------
#
# 1. A little boy is a young child
# 2. Being on the beach implies that the event is outside
#
# ================= Iteration Number 1 ==================
#
# Premise: A couple playing with a little boy on the beach.
# Hypothesis: A couple playing with a little boy on the beach.
# Explanation:
# 1. A little boy is a young child
# 2. Being on the beach implies that the event is outside
#
# -------------- Verification and Refinement -------------------
#
# ------------------ 1) Syntactic Parsing ------------------
#
# Hypothesis Sentence:
# 1. A couple are playing with a young child outside
# Subject: A couple
# Verb Phrase: are playing with a young child outside
#  - Main Verb: playing
#  - Auxiliary Verb: are
# Direct Object: a young child
# Adverbial Modifier (Location): outside
#
# Explanation Sentence:
# 1. A little boy is a young child
# Subject: A little boy
# Linking Verb: is
# Subject Complement: a young child
#
# 2. Being on the beach implies that the event is outside
# Subject: Being on the beach
# Verb Phrase: implies that the event is outside
#  - Main Verb: implies
#  - Auxiliary Verb: is
# Subject: the event
# Subject Complement: outside
#
# Premise Sentence:
# 1. A couple playing with a little boy on the beach
# Subject: A couple
# Verb Phrase: playing with a little boy on the beach
#  - Main Verb: playing
# Direct Object: a little boy
# Prepositional Phrase (Location): on the beach
#
# ------------------ 2) Neodavidsonian From ------------------
#
# Hypothesis Sentence:
# 1. A couple are playing with a young child outside.
# Logical form: ∃x y z e. Couple(x) ∧ YoungChild(y) ∧ Playing(e) ∧ Agent(e, x) ∧ Patient(e, y) ∧ Outside(e)
#
# Explanation Sentence:
# 1. A little boy is a young child.
# Logical form: ∀x. LittleBoy(x) ⟶ YoungChild(x)
#
# 2. Being on the beach implies that the event is outside.
# Logical form: ∀e. OnBeach(e) ⟶ Outside(e)
#
# Premise Sentence:
# 1. A couple playing with a little boy on the beach.
# Logical form: ∃x y z e. Couple(x) ∧ LittleBoy(y) ∧ Playing(e) ∧ Agent(e, x) ∧ Patient(e, y) ∧ OnBeach(e)
#
# ------------------ 3) Isabelle Code ------------------
#
# theory esnli_0_1
# imports Main
#
# begin
#
# typedecl entity
# typedecl event
#
# consts
#   LittleBoy :: "entity ⇒ bool"
#   YoungChild :: "entity ⇒ bool"
#   OnBeach :: "event ⇒ bool"
#   Outside :: "event ⇒ bool"
#   Couple :: "entity ⇒ bool"
#   Playing :: "event ⇒ bool"
#   Agent :: "event ⇒ entity ⇒ bool"
#   Patient :: "event ⇒ entity ⇒ bool"
#
# (* Explanation 1: A little boy is a young child. *)
# axiomatization where
#   explanation_1: "∀x. LittleBoy x ⟶ YoungChild x"
#
# (* Explanation 2: Being on the beach implies that the event is outside. *)
# axiomatization where
#   explanation_2: "∀e. OnBeach e ⟶ Outside e"
#
# theorem hypothesis:
#   (* Premise 1: A couple playing with a little boy on the beach. *)
#   assumes asm: "Couple x ∧ LittleBoy y ∧ Playing e ∧ Agent e x ∧ Patient e y ∧ OnBeach e"
#   (* Hypothesis: A couple are playing with a young child outside. *)
#   shows "∃x y z e. Couple x ∧ YoungChild y ∧ Playing e ∧ Agent e x ∧ Patient e y ∧ Outside e"
# proof -
#   (* From the premise, we can extract the known information about the couple, little boy, playing, agent, patient, and being on the beach. *)
#   from asm have "Couple x ∧ LittleBoy y ∧ Playing e ∧ Agent e x ∧ Patient e y ∧ OnBeach e" <ATP>
#   (* We can use the explanation that a little boy is a young child to infer that y is a young child. *)
#   then have "Couple x ∧ YoungChild y ∧ Playing e ∧ Agent e x ∧ Patient e y"
#     <ATP>
#   (* Now we need to show that the event is outside. We can use the explanation that being on the beach implies that the event is outside. *)
#   then have "Outside e"
#     <ATP>
#   (* Combining all the information, we can conclude the hypothesis. *)
#   then show ?thesis
#     <ATP>
# qed
#
# end
#
#
# -------------- 4) Results -------------------
#
# The explanation is logically valid!
# =====================================================
# semantic validity True
# premise A couple playing with a little boy on the beach.
# hypothesis A couple are playing with a young child outside.
# explanation A little boy is a young child.
# Being on the beach implies that the event is outside.
# refined iteration 1
# critique output {'syntactic validity': True, 'error code': '', 'solving time': 11.241818904876709, 'proof tactics': ['Sledgehammering...', 'cvc4 found a proof...', 'cvc4: Try this: using assms explanation_1 explanation_2 by blast (1 ms)', 'vampire found a proof...', 'vampire: Found duplicate proof', 'spass found a proof...', 'spass: Found duplicate proof', 'zipperposition found a proof...', 'zipperposition: Found duplicate proof', 'Done'], 'code': 'theory esnli_0_1\nimports Main\n\nbegin\n\ntypedecl entity\ntypedecl event\n\nconsts\n  LittleBoy :: "entity ⇒ bool"\n  YoungChild :: "entity ⇒ bool"\n  OnBeach :: "event ⇒ bool"\n  Outside :: "event ⇒ bool"\n  Couple :: "entity ⇒ bool"\n  Playing :: "event ⇒ bool"\n  Agent :: "event ⇒ entity ⇒ bool"\n  Patient :: "event ⇒ entity ⇒ bool"\n\n(* Explanation 1: A little boy is a young child. *)\naxiomatization where\n  explanation_1: "∀x. LittleBoy x ⟶ YoungChild x"\n\n(* Explanation 2: Being on the beach implies that the event is outside. *)\naxiomatization where\n  explanation_2: "∀e. OnBeach e ⟶ Outside e"\n\ntheorem hypothesis:\n  (* Premise 1: A couple playing with a little boy on the beach. *)\n  assumes asm: "Couple x ∧ LittleBoy y ∧ Playing e ∧ Agent e x ∧ Patient e y ∧ OnBeach e"\n  (* Hypothesis: A couple are playing with a young child outside. *)\n  shows "∃x y z e. Couple x ∧ YoungChild y ∧ Playing e ∧ Agent e x ∧ Patient e y ∧ Outside e"\nproof -\n  (* From the premise, we can extract the known information about the couple, little boy, playing, agent, patient, and being on the beach. *)\n  from asm have "Couple x ∧ LittleBoy y ∧ Playing e ∧ Agent e x ∧ Patient e y ∧ OnBeach e" <ATP>\n  (* We can use the explanation that a little boy is a young child to infer that y is a young child. *)\n  then have "Couple x ∧ YoungChild y ∧ Playing e ∧ Agent e x ∧ Patient e y" \n    <ATP>\n  (* Now we need to show that the event is outside. We can use the explanation that being on the beach implies that the event is outside. *)\n  then have "Outside e" \n    <ATP>\n  (* Combining all the information, we can conclude the hypothesis. *)\n  then show ?thesis \n    <ATP>\nqed\n\nend\n', 'logical information': 'Logical Propositions:\nA: a little boy (from Explanatory Sentence 1)\nB: a young child (from Explanatory Sentence 1)\nC: being on the beach (from Explanatory Sentence 2)\nD: the event is outside (from Explanatory Sentence 2)\n\nLogical Relations:\nEquivalent(A, B)\nEquivalent(a little boy, a young child)\n--------\nImplies(C, D)\nImplies(being on the beach, the event is outside)\n--------\n\nDerived Implications:\nImplies(B, A)\nImplies(a young child, a little boy)\n--------\nImplies(Not(A), Not(B))\nImplies(Not(a little boy), Not(a young child))\n--------\nImplies(A, B)\nImplies(a little boy, a young child)\n--------\nImplies(Not(B), Not(A))\nImplies(Not(a young child), Not(a little boy))\n--------\n'}

# %%
print("hypothesis:", results["hypothesis"])
print("premise:", results["premise"])
print("\n------------------ Explanation ----------------------\n")
print(results["explanation"])
# Out:
# hypothesis: A couple are playing with a young child outside.
# premise: A couple playing with a little boy on the beach.
#
# ------------------ Explanation ----------------------
#
# A little boy is a young child.
# Being on the beach implies that the event is outside.

# %%
results["critique output"]["proof tactics"]
# Out:
# ['Sledgehammering...',
#  'cvc4 found a proof...',
#  'cvc4: Try this: using assms explanation_1 explanation_2 by blast (1 ms)',
#  'vampire found a proof...',
#  'vampire: Found duplicate proof',
#  'spass found a proof...',
#  'spass: Found duplicate proof',
#  'zipperposition found a proof...',
#  'zipperposition: Found duplicate proof',
#  'Done']
